# %% [markdown]
# ### Exercise 33 - Apply the property of Commutativity, Associativity, Existence of neutral element and existence of muliplicative inverse for every number in {1,2,3,4}

# %% [markdown]
# ### Exercise 34
#
# $\mathbb{Z}_n^* = \{1, 2, \ldots, n - 1\}$
#
# #### Disprove
#
# - $\text{Axioms to Check:} * \text{Closure} * \text{Associativity} * \text{Identity element} (e = 1) * \text{Inverse element}$
# - $\text{Identity: } \exists e = 1 \in \mathbb{Z}_n^* \text{ such that } x \cdot e = x \text{ for all } x \in \mathbb{Z}_n^*.$
#
# To disprove the group:
# We take an example such that: $\text{The inverse of } a \text{ modulo } n \text{ exists if and only if } \text{gcd}(a, n) = 1.$ Since a and n have more than one common divisor,
#
# The example : $n = 6$, if we take $(a,b) = (2,3) \implies (2 \cdot 3) \pmod 6 = 6 \pmod 6 = 0$, shows dosent belong to commutative group.
#
# $$\text{Therefore, } (\mathbb{Z}_6^*, \cdot) \text{ is not a group, and thus } (\mathbb{Z}_n^*, \cdot) \text{ is not a group in general.}$$
#
# #### Condition
#
# $$\text{The condition is that } \mathbf{n} \text{ must be a **prime number**, } \mathbf{p}, where \space n \lt p$$

# %% [markdown]
# ### Exercise 35
#
# ${Z}_n^* = \{0, 1, 2, ..., n - 1\}$
# Order = No. of elements in this finite group => 0 to n-1 = n.
# Hence, $|G| = n$
#
# In general, for any modulus $n \ge 2$, the order of $(\mathbb{Z}_n, +)$ is $n$.

# %% [raw]
# ### Exercise 36: Checking for Generators in Modulus n
#
# #### Proving that 5 is a Generator in Modulus 6
#
# To check if an element `a` ∈ G is a generator in modulus n, we need to verify if the greatest common divisor (gcd) of `a` and `n`
# equals 1.
#
# | k, k⋅5(mod6), k⋅5, Element |
# | --- | --- |
# | 1, 1⋅5, 5, 5 |
# | 2, 2⋅5=10, 10≡4(mod6), 4 |
# | 3, 3⋅5=15, 15≡3(mod6), 3 |
# | 4, 4⋅5=20, 20≡2(mod6), 2 |
# | 5, 5⋅5=25, 25≡1(mod6), 1 |
#
# **gcd(5, 6) = 1**
#
# #### Proving that 2 is not a Generator in Modulus 6
#
# Similarly, to check if an element `a` ∈ G is a generator in modulus n, we need to verify if the gcd of `a` and `n` equals 1.
#
# | k, k⋅2(mod6), k⋅2, Element |
# | --- | --- |
# | 1, 1⋅2, 2, 2 |
# | 2, 2⋅2, 4, 4 |
# | 3, 3⋅2=6, 6≡0(mod6), 0 |
# | 4, 4⋅2=8, 8≡2(mod6), 2 (repeats) |
# | 5, 5⋅2=10, 10≡4(mod6), 4 (repeats) |
# | 6, 6⋅2=12, 12≡0(mod6), 0 |
#
# **gcd(2, 6) = 2**
#
# #### Conclusion
#
# *   **5 is a generator in modulus 6:** `gcd(5, 6) = 1`
# *   **2 is not a generator in modulus 6:** `gcd(2, 6) = 2`

# %% [markdown]
# ### Exercise 37
#
# > To show that ${Z}_5^*$ is cyclic, we need to find a generator.
# > An element $g \in G$ that is able to generate G is called a generator (Book Definition)
#
# We can show that 2 is generator in ${Z}_5^*$ :
# 1. $gcd(2,5) = 1$
# 2. you can make a table like in the previous question to check that 2 is generator.
#
# Other generators are 3 , 4
