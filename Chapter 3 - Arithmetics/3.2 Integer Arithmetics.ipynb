# %%
# Test if Sage specific math works
print(factor(2023))
plot(sin(x), (x, 0, 2*pi))
# Out:
# 7 * 17^2
# Graphics object consisting of 1 graphics primitive

# %%
#Exercise 2
print(factor(30030))
# Out:
# 2 * 3 * 5 * 7 * 11 * 13

# %%
# Exercise 3
x = var('x')
equation = 4 * x + 21 == 5
solutions = solve(equation, x)
print(solutions)
# Out:
# [
# x == -4
# ]

# %%
# Exercise 4
x = var('x')
equation = 2 * x^3 - x^2 - 2 * x + 1 == 0
solutions = solve(equation, x)
print(solutions)
# Out:
# [
# x == (1/2),
# x == -1,
# x == 1
# ]
